# %%
a = 0

def b():
    global a
    a = c(a)

def c(a):
    return a + 2


b()
b()
b()


a
# Out:
# 6

# %%
def fileLength(filename):
    try:
        with open(filename, 'r') as infile:
            contents = infile.read()
            return len(contents)
    except FileNotFoundError:
        print(f"File {filename} not found.")
        return None
print(">>> fileLength('midterm.py')")
output = fileLength('midterm.py')
if output is not None:
    print(output)

print(">>> fileLength('idterm.py')")
output = fileLength('idterm.py')
if output is not None:
    print(output)
# Out:
# >>> fileLength('midterm.py')
# File midterm.py not found.
# >>> fileLength('idterm.py')
# File idterm.py not found.

# %%
class Marsupial:
    def __init__(self):
        self.pouch = []
    
    def put_in_pouch(self, item):
        self.pouch.append(item)
    
    def pouch_contents(self):
        return self.pouch

class Kangaroo(Marsupial):
    def __init__(self, x, y):
        super().__init__()
        self.x = x
        self.y = y
    
    def jump(self, dx, dy):
        self.x += dx
        self.y += dy
    
    def __str__(self):
        return f"I am a Kangaroo located at coordinates ({self.x},{self.y})"

# Testing the classes
m = Marsupial()
m.put_in_pouch('doll')
m.put_in_pouch('firetruck')
m.put_in_pouch('kitten')
print(m.pouch_contents())
k = Kangaroo(0, 0)
print(k)
k.put_in_pouch('doll')
k.put_in_pouch('firetruck')
k.put_in_pouch('kitten')
print(k.pouch_contents())
k.jump(1, 0)
k.jump(1, 0)
k.jump(1, 0)
print(k)
# Out:
# ['doll', 'firetruck', 'kitten']
# I am a Kangaroo located at coordinates (0,0)
# ['doll', 'firetruck', 'kitten']
# I am a Kangaroo located at coordinates (3,0)

# %%
def collatz(x):
    print(x)
    if x == 1:
        return
    elif x % 2 == 0:
        collatz(x // 2)
    else:
        collatz(3 * x + 1)

collatz(1)
print("----")
collatz(10)
# Out:
# 1
# ----
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %%
def binary(n):
    if n < 2:
        print(n, end='')
    else:
        binary(n // 2)
        print(n % 2, end='')

binary(0)
print()
binary(1)
print()
binary(3)
print()
binary(9)
print()
# Out:
# 0
# 1
# 11
# 1001

# %%
from html.parser import HTMLParser

class HeadingParser(HTMLParser):
    def __init__(self):
        super().__init__()
        self.current_heading_level = None
        self.capture_data = False

    def handle_starttag(self, tag, attrs):
        if tag in ['h1', 'h2', 'h3', 'h4', 'h5', 'h6']:
            self.current_heading_level = int(tag[1]) - 1
            self.capture_data = True

    def handle_endtag(self, tag):
        if tag in ['h1', 'h2', 'h3', 'h4', 'h5', 'h6']:
            self.capture_data = False
            self.current_heading_level = None             

    def handle_data(self, data):
        if self.capture_data and self.current_heading_level is not None:
            print(" " * self.current_heading_level + data.strip())

infile = open('w3c.html')
content = infile.read()
infile.close()

hp = HeadingParser()
hp.feed(content)
# Out:
# W3C Mission
#  Principles

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

def webdir(url, depth, indent):
    print(' ' * indent + url)
    
    if depth <= 0:
        return
    
    try:
        response = requests.get(url)
        response.raise_for_status() 
        
        soup = BeautifulSoup(response.text, 'html.parser')
        
        for link in soup.find_all('a', href=True):
            
            full_url = urljoin(url, link['href'])
           
            webdir(full_url, depth - 1, indent + 4)  
            
    except (requests.RequestException, Exception) as e:
        print(' ' * indent + f"Error fetching {url}: {e}")


webdir('https://html5test.com/', 2, 0)
# Out:
# https://html5test.com/
#     https://html5test.com/index.html
#         https://html5test.com/index.html
#         https://html5test.com/about.html
#         https://html5test.co/
#         https://www.paypal.com/cgi-bin/webscr?cmd=_s-xclick&hosted_button_id=9DNBJPQFEHYSC
#         https://www.twitter.com/html5test
#         https://html5test.com/cdn-cgi/l/email-protection#7d14131b123d150910114809180e09531e1210
#         https://github.com/NielsLeenheer/html5test
#         http://www.w3.org/
#         http://whichbrowser.net
#     https://html5test.com/about.html
#         https://html5test.com/index.html
#         https://html5test.com/about.html
#         https://html5test.com/about.html
#         https://github.com/NielsLeenheer/html5test
#         http://www.w3.org/
#         http://whichbrowser.net
#     https://html5test.co/
#         https://html5test.co/
#         https://html5test.co/results/desktop.html
#         https://html5test.co/compare/browser/
# ...

# %%
import sqlite3
import pandas as pd

connection = sqlite3.connect('Python')

cursor = connection.cursor()

cursor.execute('''
CREATE TABLE IF NOT EXISTS WeatherData (
    City TEXT,
    Country TEXT,
    Season TEXT,
    Temperature REAL,
    Rainfall REAL
)
''')

data = [
    ('Mumbai', 'India', 'Winter', 24.8, 5.9),
    ('Mumbai', 'India', 'Spring', 28.4, 16.2),
    ('Mumbai', 'India', 'Summer', 27.9, 1549.4),
    ('Mumbai', 'India', 'Fall', 27.6, 346.0),
    ('London', 'United Kingdom', 'Winter', 4.2, 207.7),
    ('London', 'United Kingdom', 'Spring', 8.3, 169.6),
    ('London', 'United Kingdom', 'Summer', 15.7, 157.0),
    ('London', 'United Kingdom', 'Fall', 10.4, 218.5),
    ('Cairo', 'Egypt', 'Winter', 13.6, 16.5),
    ('Cairo', 'Egypt', 'Spring', 20.7, 6.5),
    ('Cairo', 'Egypt', 'Summer', 27.7, 0.1),
    ('Cairo', 'Egypt', 'Fall', 22.2, 4.5)
]

cursor.executemany('''
INSERT INTO WeatherData (City, Country, Season, Temperature, Rainfall)
VALUES (?, ?, ?, ?, ?)
''', data)

connection.commit()

def run_query(query):
    return pd.read_sql_query(query, connection)

# a) All the temperature data
temperature_data = run_query("SELECT Temperature FROM WeatherData")
print("Temperature Data:")
print(temperature_data)

# b) All the cities, but without repetition
cities = run_query("SELECT DISTINCT City FROM WeatherData")
print("\nUnique Cities:")
print(cities)

# c) All the records for India
india_records = run_query("SELECT * FROM WeatherData WHERE Country = 'India'")
print("\nRecords for India:")
print(india_records)

# d) All the Fall records
fall_records = run_query("SELECT * FROM WeatherData WHERE Season = 'Fall'")
print("\nFall Records:")
print(fall_records)

# e) City, country, and season for which average rainfall is between 200 and 400 mm
avg_rainfall = run_query("""
SELECT City, Country, Season
FROM WeatherData
GROUP BY City, Country, Season
HAVING AVG(Rainfall) BETWEEN 200 AND 400
""")
print("\nCities with Average Rainfall Between 200 and 400 mm:")
print(avg_rainfall)

# f) City and country for which average Fall temperature is above 20 degrees, in increasing order
avg_fall_temp = run_query("""
SELECT City, Country
FROM WeatherData
WHERE Season = 'Fall'
GROUP BY City, Country
HAVING AVG(Temperature) > 20
ORDER BY AVG(Temperature) ASC
""")
print("\nCities with Average Fall Temperature Above 20 Degrees (Ordered):")
print(avg_fall_temp)

# g) Total annual rainfall for Cairo
total_rainfall_cairo = run_query("SELECT SUM(Rainfall) AS Total_Annual_Rainfall FROM WeatherData WHERE City = 'Cairo'")
print("\nTotal Annual Rainfall for Cairo:")
print(total_rainfall_cairo)

# h) Total rainfall for each season
total_rainfall_per_season = run_query("SELECT Season, SUM(Rainfall) AS Total_Rainfall FROM WeatherData GROUP BY Season")
print("\nTotal Rainfall for Each Season:")
print(total_rainfall_per_season)

# Step 5: Close the Connection
connection.close()
# Out:
# Temperature Data:
#     Temperature
# 0          24.8
# 1          28.4
# 2          27.9
# 3          27.6
# 4           4.2
# 5           8.3
# 6          15.7
# 7          10.4
# 8          13.6
# 9          20.7
# 10         27.7
# 11         22.2
#
# Unique Cities:
#      City
# 0  Mumbai
# 1  London
# 2   Cairo
#
# Records for India:
#      City Country  Season  Temperature  Rainfall
# 0  Mumbai   India  Winter         24.8       5.9
# 1  Mumbai   India  Spring         28.4      16.2
# 2  Mumbai   India  Summer         27.9    1549.4
# 3  Mumbai   India    Fall         27.6     346.0
#
# Fall Records:
#      City         Country Season  Temperature  Rainfall
# 0  Mumbai           India   Fall         27.6     346.0
# 1  London  United Kingdom   Fall         10.4     218.5
# 2   Cairo           Egypt   Fall         22.2       4.5
#
# Cities with Average Rainfall Between 200 and 400 mm:
#      City         Country  Season
# 0  London  United Kingdom    Fall
# ...

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# a) List with all words in uppercase
uppercase_words = [word.upper() for word in words]
print(uppercase_words)

# b) List with all words in lowercase
lowercase_words = [word.lower() for word in words]
print(lowercase_words)

# c) List of lengths of each word in list words
word_lengths = [len(word) for word in words]
print(word_lengths)

# d) List containing a list for each word with uppercase, lowercase, and length
word_details = [[word.upper(), word.lower(), len(word)] for word in words]
print(word_details)

# e) List of words containing 4 or more characters
long_words = [word for word in words if len(word) >= 4]
print(long_words)
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# [3, 5, 5, 3, 5, 4, 3, 4, 3]
# [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]
# ['quick', 'brown', 'jumps', 'over', 'lazy']
